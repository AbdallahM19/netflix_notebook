# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


netflix_df = pd.read_csv('netflix_data.csv')

# %%
# Load the dataset using Pandas and display the first 5 rows.
netflix_df.head()
# Out:
#   show_id     type  title           director  \
# 0      s2    Movie   7:19  Jorge Michel Grau
# 1      s3    Movie  23:59       Gilbert Chan
# 2      s4    Movie      9        Shane Acker
# 3      s5    Movie     21     Robert Luketic
# 4      s6  TV Show     46        Serdar Akar
#
#                                                 cast        country  \
# 0  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 1  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 2  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 3  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 4  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#           date_added  release_year  duration  \
# 0  December 23, 2016          2016        93
# 1  December 20, 2018          2011        78
# 2  November 16, 2017          2009        80
# 3    January 1, 2020          2008       123
# 4       July 1, 2017          2016         1
#
# ...

# %%
# Check the number of rows and columns in the dataset.
netflix_df.shape
# Out:
# (4812, 11)

# %%
# List all column names in the dataset.
netflix_df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'duration', 'description', 'genre'],
#       dtype='object')

# %%
# Check for missing values and print the count of missing values per column.
netflix_df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# duration        0
# description     0
# genre           0
# dtype: int64

# %%
# Get summary statistics (mean, min, max, etc.) for numerical columns.
netflix_df.describe()
# Out:
#        release_year     duration
# count   4812.000000  4812.000000
# mean    2012.711554    99.566708
# std        9.517978    30.889305
# min     1942.000000     1.000000
# 25%     2011.000000    88.000000
# 50%     2016.000000    99.000000
# 75%     2018.000000   116.000000
# max     2021.000000   253.000000

# %%
# Find the number of unique values in each column.
netflix_df.nunique()
# Out:
# show_id         4812
# type               2
# title           4812
# director        3615
# cast            4690
# country           72
# date_added      1292
# release_year      71
# duration         193
# description     4807
# genre             31
# dtype: int64

# %%
# Find the most common movie/TV show genre in the dataset.
netflix_df['genre'].value_counts().idxmax()
# Out:
# 'Dramas'

# %%
# Filter the dataset to show only movies released after 2015.
netflix_df[netflix_df["release_year"] == 2015]
# Out:
#      show_id   type                title            director  \
# 28       s41  Movie          Çarsi Pazar     Muharrem Gülmez
# 42       s63  Movie           13 Cameras      Victor Zarcoff
# 66       s99  Movie        3 Generations         Gaby Dellal
# 69      s103  Movie  3 Türken & ein Baby         Sinan Akkuş
# 79      s116  Movie          4th Man Out      Andrew Nackman
# ...      ...    ...                  ...                 ...
# 4766   s7709  Movie        Yes or No 2.5   Kirati Nakintanon
# 4775   s7727  Movie         You Carry Me          Ivona Juka
# 4780   s7733  Movie       You're My Boss  Antoinette Jadaone
# 4801   s7771  Movie              Zinzana     Majid Al Ansari
# 4811   s7784  Movie               Zubaan         Mozez Singh
#
#                                                    cast        country  \
# 28    Erdem Yener, Ayhan Taş, Emin Olcay, Muharrem G...         Turkey
# 42    PJ McCabe, Brianne Moncrief, Sarah Baldwin, Ji...  United States
# ...

# %%
# Find the top 5 directors with the most content on Netflix.
netflix_df['director'].value_counts().head()
# Out:
# director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              15
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Name: count, dtype: int64

# %%
# Visualize the distribution of movie release years using a histogram (use Matplotlib or Seaborn).
plt.hist(
    netflix_df['release_year'],
    bins=netflix_df['release_year'].nunique(),
)
plt.xlabel('Release Year')
plt.ylabel('Number of Movies')
plt.title('Distribution of Movie Release Years')
plt.show()
